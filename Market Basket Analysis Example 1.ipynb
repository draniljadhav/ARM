# %% [markdown]
# In this lab excercise you will learn how to do market basket analysis using apriori algorithm.

# %% [markdown]
# Install  __mlxtend__ library from anaconda prompt

# %%
#import all required classes for market basket analysis from mlxtedn library
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# # Example 1

# %% [markdown]
# In this example instead of reading data from external sources we are going to
# create small transaction dataset to understand how to generate rules from
# sample transaction dataset using apriori algorithm. Transaction dataset contains only three transactions as follows

# %%
sample_transactions_data = [['milk', 'bread', 'water'],['coffe', 'sugar','water' ],['burgers', 'eggs','bread']]

# %%
sample_transactions_data
# Out:
# [['milk', 'bread', 'water'],
#  ['coffe', 'sugar', 'water'],
#  ['burgers', 'eggs', 'bread']]

# %% [markdown]
# To use apriori algorithm on transaction dataset, requirement is that data should be in tabular
# format where each row represents transaction and column represents existance of
# item in transaction. So let us first transform transaction data to the format required by algorithm.
# No. of rows=no. of transactions (baskets to be alalyzed)
# No. of columns=all unique items present in all transactions

# %%
#instantiate TransactionEncoder
#it is required to convert data into required format (where each row represents transaction and column 
#represents presence of item in transaction)
transaction_encoder = TransactionEncoder()

# %%
#fit and transform data
transaction_array= transaction_encoder.fit(sample_transactions_data).transform(sample_transactions_data)

# %%
transaction_array
# Out:
# array([[ True, False, False, False,  True, False,  True],
#        [False, False,  True, False, False,  True,  True],
#        [ True,  True, False,  True, False, False, False]])

# %%
#import pandas library
import pandas as pd

# %%
#Create data frame
transaction_data = pd.DataFrame(transaction_array, columns=transaction_encoder.columns_)
#te.columns_ returns column names. column names are the names of all items in all transactions

# %%
#display data - the format now is as per requirement of algorithm
transaction_data
# Out:
#    bread  burgers  coffe   eggs   milk  sugar  water
# 0   True    False  False  False   True  False   True
# 1  False    False   True  False  False   True   True
# 2   True     True  False   True  False  False  False

# %%
#find dimensions of data
transaction_data.shape
# Out:
# (3, 7)

# %%
#find frequent itemsets in the data with specified support count using apriori algorithm
frequent_itemsets = apriori(transaction_data, min_support=0.3, use_colnames=True)
#if you don't set use_colnames=True, it returns column index instead of column name (item name)

# %%
#display frequent itemsets. 
frequent_itemsets
# Out:
#      support                itemsets
# 0   0.666667                 (bread)
# 1   0.333333               (burgers)
# 2   0.333333                 (coffe)
# 3   0.333333                  (eggs)
# 4   0.333333                  (milk)
# 5   0.333333                 (sugar)
# 6   0.666667                 (water)
# 7   0.333333        (burgers, bread)
# 8   0.333333           (bread, eggs)
# 9   0.333333           (milk, bread)
# 10  0.333333          (water, bread)
# 11  0.333333         (burgers, eggs)
# 12  0.333333          (coffe, sugar)
# 13  0.333333          (coffe, water)
# 14  0.333333           (water, milk)
# 15  0.333333          (water, sugar)
# 16  0.333333  (burgers, bread, eggs)
# 17  0.333333    (water, milk, bread)
# 18  0.333333   (coffe, sugar, water)

# %%
#generate rules from frequent itemsets by specifying threshold for confidence or lift
rules= association_rules(frequent_itemsets, metric="confidence", min_threshold=.6)

# %%
#display rules
rules
# Out:
#          antecedents       consequents  antecedent support  \
# 0          (burgers)           (bread)            0.333333
# 1             (eggs)           (bread)            0.333333
# 2             (milk)           (bread)            0.333333
# 3             (eggs)         (burgers)            0.333333
# 4          (burgers)            (eggs)            0.333333
# 5            (sugar)           (coffe)            0.333333
# 6            (coffe)           (sugar)            0.333333
# 7            (coffe)           (water)            0.333333
# 8             (milk)           (water)            0.333333
# 9            (sugar)           (water)            0.333333
# 10     (eggs, bread)         (burgers)            0.333333
# 11   (eggs, burgers)           (bread)            0.333333
# 12  (bread, burgers)            (eggs)            0.333333
# 13            (eggs)  (bread, burgers)            0.333333
# 14         (burgers)     (eggs, bread)            0.333333
# 15     (milk, water)           (bread)            0.333333
# 16    (water, bread)            (milk)            0.333333
# 17     (milk, bread)           (water)            0.333333
# 18            (milk)    (water, bread)            0.333333
# 19    (sugar, water)           (coffe)            0.333333
# 20    (coffe, water)           (sugar)            0.333333
# 21    (sugar, coffe)           (water)            0.333333
# 22           (sugar)    (coffe, water)            0.333333
# 23           (coffe)    (sugar, water)            0.333333
#
#     consequent support   support  confidence  lift  leverage  conviction
# 0             0.666667  0.333333         1.0   1.5  0.111111         inf
# 1             0.666667  0.333333         1.0   1.5  0.111111         inf
# 2             0.666667  0.333333         1.0   1.5  0.111111         inf
# 3             0.333333  0.333333         1.0   3.0  0.222222         inf
# 4             0.333333  0.333333         1.0   3.0  0.222222         inf
# 5             0.333333  0.333333         1.0   3.0  0.222222         inf
# 6             0.333333  0.333333         1.0   3.0  0.222222         inf
# 7             0.666667  0.333333         1.0   1.5  0.111111         inf
# 8             0.666667  0.333333         1.0   1.5  0.111111         inf
# 9             0.666667  0.333333         1.0   1.5  0.111111         inf
# 10            0.333333  0.333333         1.0   3.0  0.222222         inf
# 11            0.666667  0.333333         1.0   1.5  0.111111         inf
# 12            0.333333  0.333333         1.0   3.0  0.222222         inf
# 13            0.333333  0.333333         1.0   3.0  0.222222         inf
# 14            0.333333  0.333333         1.0   3.0  0.222222         inf
# 15            0.666667  0.333333         1.0   1.5  0.111111         inf
# 16            0.333333  0.333333         1.0   3.0  0.222222         inf
# 17            0.666667  0.333333         1.0   1.5  0.111111         inf
# 18            0.333333  0.333333         1.0   3.0  0.222222         inf
# 19            0.333333  0.333333         1.0   3.0  0.222222         inf
# 20            0.333333  0.333333         1.0   3.0  0.222222         inf
# 21            0.666667  0.333333         1.0   1.5  0.111111         inf
# 22            0.333333  0.333333         1.0   3.0  0.222222         inf
# 23            0.333333  0.333333         1.0   3.0  0.222222         inf

# %%
#Now display rule with lift greater than 1
rules[rules['lift']>1]
# Out:
#          antecedents       consequents  antecedent support  \
# 0          (burgers)           (bread)            0.333333
# 1             (eggs)           (bread)            0.333333
# 2             (milk)           (bread)            0.333333
# 3             (eggs)         (burgers)            0.333333
# 4          (burgers)            (eggs)            0.333333
# 5            (sugar)           (coffe)            0.333333
# 6            (coffe)           (sugar)            0.333333
# 7            (coffe)           (water)            0.333333
# 8             (milk)           (water)            0.333333
# 9            (sugar)           (water)            0.333333
# 10     (eggs, bread)         (burgers)            0.333333
# 11   (eggs, burgers)           (bread)            0.333333
# 12  (bread, burgers)            (eggs)            0.333333
# 13            (eggs)  (bread, burgers)            0.333333
# 14         (burgers)     (eggs, bread)            0.333333
# 15     (milk, water)           (bread)            0.333333
# 16    (water, bread)            (milk)            0.333333
# 17     (milk, bread)           (water)            0.333333
# 18            (milk)    (water, bread)            0.333333
# 19    (sugar, water)           (coffe)            0.333333
# 20    (coffe, water)           (sugar)            0.333333
# 21    (sugar, coffe)           (water)            0.333333
# 22           (sugar)    (coffe, water)            0.333333
# 23           (coffe)    (sugar, water)            0.333333
#
#     consequent support   support  confidence  lift  leverage  conviction
# 0             0.666667  0.333333         1.0   1.5  0.111111         inf
# 1             0.666667  0.333333         1.0   1.5  0.111111         inf
# 2             0.666667  0.333333         1.0   1.5  0.111111         inf
# 3             0.333333  0.333333         1.0   3.0  0.222222         inf
# 4             0.333333  0.333333         1.0   3.0  0.222222         inf
# 5             0.333333  0.333333         1.0   3.0  0.222222         inf
# 6             0.333333  0.333333         1.0   3.0  0.222222         inf
# 7             0.666667  0.333333         1.0   1.5  0.111111         inf
# 8             0.666667  0.333333         1.0   1.5  0.111111         inf
# 9             0.666667  0.333333         1.0   1.5  0.111111         inf
# 10            0.333333  0.333333         1.0   3.0  0.222222         inf
# 11            0.666667  0.333333         1.0   1.5  0.111111         inf
# 12            0.333333  0.333333         1.0   3.0  0.222222         inf
# 13            0.333333  0.333333         1.0   3.0  0.222222         inf
# 14            0.333333  0.333333         1.0   3.0  0.222222         inf
# 15            0.666667  0.333333         1.0   1.5  0.111111         inf
# 16            0.333333  0.333333         1.0   3.0  0.222222         inf
# 17            0.666667  0.333333         1.0   1.5  0.111111         inf
# 18            0.333333  0.333333         1.0   3.0  0.222222         inf
# 19            0.333333  0.333333         1.0   3.0  0.222222         inf
# 20            0.333333  0.333333         1.0   3.0  0.222222         inf
# 21            0.666667  0.333333         1.0   1.5  0.111111         inf
# 22            0.333333  0.333333         1.0   3.0  0.222222         inf
# 23            0.333333  0.333333         1.0   3.0  0.222222         inf

# %%
#display only LHS, RHS, support of rule , confidence of the rule and lift value
#rules.loc[:,['antecedents','consequents','support','support','confidence','lift']]
rules[['antecedents','consequents','support','confidence','lift']]
# Out:
#          antecedents       consequents   support  confidence  lift
# 0          (burgers)           (bread)  0.333333         1.0   1.5
# 1             (eggs)           (bread)  0.333333         1.0   1.5
# 2             (milk)           (bread)  0.333333         1.0   1.5
# 3             (eggs)         (burgers)  0.333333         1.0   3.0
# 4          (burgers)            (eggs)  0.333333         1.0   3.0
# 5            (sugar)           (coffe)  0.333333         1.0   3.0
# 6            (coffe)           (sugar)  0.333333         1.0   3.0
# 7            (coffe)           (water)  0.333333         1.0   1.5
# 8             (milk)           (water)  0.333333         1.0   1.5
# 9            (sugar)           (water)  0.333333         1.0   1.5
# 10     (eggs, bread)         (burgers)  0.333333         1.0   3.0
# 11   (eggs, burgers)           (bread)  0.333333         1.0   1.5
# 12  (bread, burgers)            (eggs)  0.333333         1.0   3.0
# 13            (eggs)  (bread, burgers)  0.333333         1.0   3.0
# 14         (burgers)     (eggs, bread)  0.333333         1.0   3.0
# 15     (milk, water)           (bread)  0.333333         1.0   1.5
# 16    (water, bread)            (milk)  0.333333         1.0   3.0
# 17     (milk, bread)           (water)  0.333333         1.0   1.5
# 18            (milk)    (water, bread)  0.333333         1.0   3.0
# 19    (sugar, water)           (coffe)  0.333333         1.0   3.0
# 20    (coffe, water)           (sugar)  0.333333         1.0   3.0
# 21    (sugar, coffe)           (water)  0.333333         1.0   1.5
# 22           (sugar)    (coffe, water)  0.333333         1.0   3.0
# 23           (coffe)    (sugar, water)  0.333333         1.0   3.0

# %%
for i in range(23):
    print(rules.iloc[i]['antecedents'],"->",rules.iloc[i]['consequents'],"support=",rules.iloc[i]['support'],"confidence=",rules.iloc[i]['confidence'],"lift=",rules.iloc[i]['lift'])
# Out:
# frozenset({'burgers'}) -> frozenset({'bread'}) support= 0.3333333333333333 confidence= 1.0 lift= 1.5
# frozenset({'eggs'}) -> frozenset({'bread'}) support= 0.3333333333333333 confidence= 1.0 lift= 1.5
# frozenset({'milk'}) -> frozenset({'bread'}) support= 0.3333333333333333 confidence= 1.0 lift= 1.5
# frozenset({'eggs'}) -> frozenset({'burgers'}) support= 0.3333333333333333 confidence= 1.0 lift= 3.0
# frozenset({'burgers'}) -> frozenset({'eggs'}) support= 0.3333333333333333 confidence= 1.0 lift= 3.0
# frozenset({'sugar'}) -> frozenset({'coffe'}) support= 0.3333333333333333 confidence= 1.0 lift= 3.0
# frozenset({'coffe'}) -> frozenset({'sugar'}) support= 0.3333333333333333 confidence= 1.0 lift= 3.0
# frozenset({'coffe'}) -> frozenset({'water'}) support= 0.3333333333333333 confidence= 1.0 lift= 1.5
# frozenset({'milk'}) -> frozenset({'water'}) support= 0.3333333333333333 confidence= 1.0 lift= 1.5
# frozenset({'sugar'}) -> frozenset({'water'}) support= 0.3333333333333333 confidence= 1.0 lift= 1.5
# frozenset({'eggs', 'bread'}) -> frozenset({'burgers'}) support= 0.3333333333333333 confidence= 1.0 lift= 3.0
# frozenset({'eggs', 'burgers'}) -> frozenset({'bread'}) support= 0.3333333333333333 confidence= 1.0 lift= 1.5
# frozenset({'bread', 'burgers'}) -> frozenset({'eggs'}) support= 0.3333333333333333 confidence= 1.0 lift= 3.0
# frozenset({'eggs'}) -> frozenset({'bread', 'burgers'}) support= 0.3333333333333333 confidence= 1.0 lift= 3.0
# frozenset({'burgers'}) -> frozenset({'eggs', 'bread'}) support= 0.3333333333333333 confidence= 1.0 lift= 3.0
# frozenset({'milk', 'water'}) -> frozenset({'bread'}) support= 0.3333333333333333 confidence= 1.0 lift= 1.5
# frozenset({'water', 'bread'}) -> frozenset({'milk'}) support= 0.3333333333333333 confidence= 1.0 lift= 3.0
# frozenset({'milk', 'bread'}) -> frozenset({'water'}) support= 0.3333333333333333 confidence= 1.0 lift= 1.5
# frozenset({'milk'}) -> frozenset({'water', 'bread'}) support= 0.3333333333333333 confidence= 1.0 lift= 3.0
# frozenset({'sugar', 'water'}) -> frozenset({'coffe'}) support= 0.3333333333333333 confidence= 1.0 lift= 3.0
# frozenset({'coffe', 'water'}) -> frozenset({'sugar'}) support= 0.3333333333333333 confidence= 1.0 lift= 3.0
# frozenset({'sugar', 'coffe'}) -> frozenset({'water'}) support= 0.3333333333333333 confidence= 1.0 lift= 1.5
# frozenset({'sugar'}) -> frozenset({'coffe', 'water'}) support= 0.3333333333333333 confidence= 1.0 lift= 3.0
